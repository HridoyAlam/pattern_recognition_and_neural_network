# %%
import pandas as pd
import numpy as np

# %%
raw_df = pd.read_csv('results1.csv')
df = raw_df.copy()
df.head()
# Out:
#    Unnamed: 0               team_1          team_2     _map  result_1  \
# 0           0              Recon 5         TeamOne    Dust2         0
# 1           1              Recon 5         TeamOne  Inferno        13
# 2           2  New England Whalers        Station7  Inferno        12
# 3           3              Rugratz  Bad News Bears  Inferno         7
# 4           4              Rugratz  Bad News Bears  Vertigo         8
#
#    result_2  map_winner  starting_ct  ct_1  t_2  t_1  ct_2  event_id  \
# 0        16           2            2     0    1    0    15      5151
# 1        16           2            2     8    6    5    10      5151
# 2        16           2            1     9    6    3    10      5243
# 3        16           2            2     0    8    7     8      5151
# 4        16           2            2     4    5    4    11      5151
#
#    match_id  rank_1  rank_2  map_wins_1  map_wins_2  match_winner
# ...

# %%
#those match when Recon 5 win
df.loc[(df['team_1'] == 'Recon 5') & (df['match_winner'] == 1)]
# Out:
#       Unnamed: 0   team_1               team_2      _map  result_1  result_2  \
# 37            37  Recon 5              Oceanus      Nuke        16         5
# 248          248  Recon 5             Monstars   Inferno        16         9
# 520          520  Recon 5  New England Whalers      Nuke        16         5
# 585          585  Recon 5             Infinity     Train        16        12
# 1083        1083  Recon 5              Rugratz   Inferno        25        22
# 1084        1084  Recon 5              Rugratz   Vertigo        16        14
# 1085        1085  Recon 5              Rugratz  Overpass        13        16
# 1241        1241  Recon 5            Polar Ace     Dust2        16        11
# 1249        1249  Recon 5              Oceanus   Vertigo        16         8
# 2952        2952  Recon 5                Faint   Inferno        16         4
# 2954        2954  Recon 5                Faint    Mirage        16        13
# ...

# %%
#those match when Recon 5 loss
df.loc[(df['team_1'] == 'Recon 5') & (df['match_winner'] != 1)]
# Out:
#    Unnamed: 0   team_1   team_2     _map  result_1  result_2  map_winner  \
# 0           0  Recon 5  TeamOne    Dust2         0        16           2
# 1           1  Recon 5  TeamOne  Inferno        13        16           2
#
#    starting_ct  ct_1  t_2  t_1  ct_2  event_id  match_id  rank_1  rank_2  \
# 0            2     0    1    0    15      5151   2340454      62      63
# 1            2     8    6    5    10      5151   2340454      62      63
#
#    map_wins_1  map_wins_2  match_winner
# 0           0           2             2
# 1           0           2             2

# %%
#any two team match results

df.loc[(df['team_1'] == 'Recon 5') & (df['team_2'] == 'Rugratz')]
# Out:
#       Unnamed: 0   team_1   team_2      _map  result_1  result_2  map_winner  \
# 1083        1083  Recon 5  Rugratz   Inferno        25        22           1
# 1084        1084  Recon 5  Rugratz   Vertigo        16        14           1
# 1085        1085  Recon 5  Rugratz  Overpass        13        16           2
#
#       starting_ct  ct_1  t_2  t_1  ct_2  event_id  match_id  rank_1  rank_2  \
# 1083            1     8    7    7     8      5212   2339461     149      72
# 1084            2     7    8    9     6      5212   2339461     149      72
# 1085            1     7    8    6     8      5212   2339461     149      72
#
#       map_wins_1  map_wins_2  match_winner
# 1083           2           1             1
# 1084           2           1             1
# 1085           2           1             1

# %%
# number of #any two team match results
num = len(df.loc[(df['team_1'] == 'Recon 5') & (df['team_2'] == 'Rugratz')])
num
# Out:
# 3

# %%
# number of #any two team match results || when team_1 win
team_1_win = len(df.loc[(df['team_1'] == 'Recon 5') & (df['team_2'] == 'Rugratz') & (df['match_winner'] == 1)])
team_1_win
# Out:
# 3

# %%
# number of #any two team match results || when team_2 win
team_2_win = len(df.loc[(df['team_1'] == 'Recon 5') & (df['team_2'] == 'Rugratz') & (df['match_winner'] == 2)])
team_2_win
# Out:
# 0
